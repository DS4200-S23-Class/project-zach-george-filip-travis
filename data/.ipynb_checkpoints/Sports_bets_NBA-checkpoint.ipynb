# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import json
from pathlib import Path


#Source: https://the-odds-api.com/
url = f'https://api.the-odds-api.com/v4/sports/basketball_nba/odds/?daysFrom=3&apiKey=eaa265db381b34b1dbe2ce35e2628048&regions=us&markets=h2h,spreads&oddsFormat=american'
betting_text = requests.get(url).text
betting_data = json.loads(betting_text)

# %%
# Length of the betting_data
len(betting_data)
print(betting_data)
# Out:
# [{'id': '8aa4612b180d52ecb170150491f9a34d', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2023-04-05T23:10:00Z', 'home_team': 'Detroit Pistons', 'away_team': 'Brooklyn Nets', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-05T20:13:33Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:13:33Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -580}, {'name': 'Detroit Pistons', 'price': 440}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:13:33Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -11.0}, {'name': 'Detroit Pistons', 'price': -110, 'point': 11.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-05T20:13:33Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:13:33Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -580}, {'name': 'Detroit Pistons', 'price': 430}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:13:33Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -11.0}, {'name': 'Detroit Pistons', 'price': -110, 'point': 11.0}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-04-05T20:13:33Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:13:33Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -556}, {'name': 'Detroit Pistons', 'price': 430}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:13:33Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -114, 'point': -11.0}, {'name': 'Detroit Pistons', 'price': -108, 'point': 11.0}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-04-05T20:10:28Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:10:28Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -549}, {'name': 'Detroit Pistons', 'price': 430}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:10:28Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -108, 'point': -11.0}, {'name': 'Detroit Pistons', 'price': -102, 'point': 11.0}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-05T20:11:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:11:44Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -600}, {'name': 'Detroit Pistons', 'price': 430}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:11:44Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -11.5}, {'name': 'Detroit Pistons', 'price': -110, 'point': 11.5}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2023-04-05T20:13:34Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:13:34Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -588}, {'name': 'Detroit Pistons', 'price': 420}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:13:34Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -11.0}, {'name': 'Detroit Pistons', 'price': -110, 'point': 11.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2023-04-05T20:11:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:11:45Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -550}, {'name': 'Detroit Pistons', 'price': 415}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:11:45Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -11.0}, {'name': 'Detroit Pistons', 'price': -110, 'point': 11.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-05T20:11:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:11:44Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -575}, {'name': 'Detroit Pistons', 'price': 425}]}, {'key': 'spreads', 'last_update': '2023-04-05T20:11:44Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -11.0}, {'name': 'Detroit Pistons', 'price': -110, 'point': 11.0}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-05T20:13:33Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-05T20:13:33Z', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -550}, {'name': 'Detroit Pistons', 'price': 410}]}, {'key' ...

# %%
# looking betting data
sites_list = list()
for game in betting_data:
    bookmakers = game['bookmakers']
    for site in bookmakers:
        sites_list.append(site['title'])

# %%
sites_list = list(set(sites_list))

# %%
#init a dictionary so that we get our first look at the data
data_by_game = dict()



for game in betting_data:
    # Get the home team and away team by game and format it for easier viewing
    
    home = game['home_team']
    away = game['away_team']
    
    matchup = f'{away} @ {home}'
    
    # Keep the matchup name as the key, will store odds by site as value
    data_by_game[matchup] = dict()
    
    bookmakers = game['bookmakers']
    for site in bookmakers:
        site_title = site['title']
        data_by_game[matchup][site_title] = dict()
        markets = site['markets']
        
        for market in markets:
            bet_format = market['key']
            data_by_game[matchup][site_title][bet_format] = market['outcomes']
                     
#import pretty printer
import pprint

#this library helps us see all of the nested dictionaries 
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(data_by_game)
# Out:
# {   'Brooklyn Nets @ Detroit Pistons': {   'Barstool Sportsbook': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                              'Nets',
#                                                                                      'price': -590},
#                                                                                  {   'name': 'Detroit '
#                                                                                              'Pistons',
#                                                                                      'price': 430}],
#                                                                       'spreads': [   {   'name': 'Brooklyn '
#                                                                                                  'Nets',
#                                                                                          'point': -11.0,
#                                                                                          'price': -110},
#                                                                                      {   'name': 'Detroit '
#                                                                                                  'Pistons',
#                                                                                          'point': 11.0,
#                                                                                          'price': -110}]},
#                                            'BetMGM': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                 'Nets',
#                                                                         'price': -550},
#                                                                     {   'name': 'Detroit '
#                                                                                 'Pistons',
#                                                                         'price': 400}],
#                                                          'spreads': [   {   'name': 'Brooklyn '
#                                                                                     'Nets',
#                                                                             'point': -11.5,
#                                                                             'price': -105},
#                                                                         {   'name': 'Detroit '
#                                                                                     'Pistons',
#                                                                             'point': 11.5,
#                                                                             'price': -115}]},
#                                            'BetOnline.ag': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                       'Nets',
#                                                                               'price': -556},
#                                                                           {   'name': 'Detroit '
#                                                                                       'Pistons',
#                                                                               'price': 430}],
#                                                                'spreads': [   {   'name': 'Brooklyn '
#                                                                                           'Nets',
#                                                                                   'point': -11.0,
#                                                                                   'price': -114},
#                                                                               {   'name': 'Detroit '
#                                                                                           'Pistons',
#                                                                                   'point': 11.0,
#                                                                                   'price': -108}]},
#                                            'BetRivers': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                    'Nets',
#                                                                            'price': -590},
#                                                                        {   'name': 'Detroit '
#                                                                                    'Pistons',
#                                                                            'price': 430}],
#                                                             'spreads': [   {   'name': 'Brooklyn '
#                                                                                        'Nets',
#                                                                                'point': -11.0,
#                                                                                'price': -110},
#                                                                            {   'name': 'Detroit '
#                                                                                        'Pistons',
#                                                                                'point': 11.0,
#                                                                                'price': -110}]},
#                                            'BetUS': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                'Nets',
#                                                                        'price': -550},
#                                                                    {   'name': 'Detroit '
#                                                                                'Pistons',
#                                                                        'price': 415}],
#                                                         'spreads': [   {   'name': 'Brooklyn '
#                                                                                    'Nets',
#                                                                            'point': -11.0,
#                                                                            'price': -110},
#                                                                        {   'name': 'Detroit '
#                                                                                    'Pistons',
#                                                                            'point': 11.0,
#                                                                            'price': -110}]},
#                                            'Bovada': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                 'Nets',
#                                                                         'price': -585},
#                                                                     {   'name': 'Detroit '
#                                                                                 'Pistons',
#                                                                         'price': 410}],
#                                                          'spreads': [   {   'name': 'Brooklyn '
#                                                                                     'Nets',
#                                                                             'point': -11.0,
#                                                                             'price': -110},
#                                                                         {   'name': 'Detroit '
#                                                                                     'Pistons',
#                                                                             'point': 11.0,
#                                                                             'price': -110}]},
#                                            'Circa Sports': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                       'Nets',
#                                                                               'price': -667},
#                                                                           {   'name': 'Detroit '
#                                                                                       'Pistons',
#                                                                               'price': 447}],
#                                                                'spreads': [   {   'name': 'Brooklyn '
#                                                                                           'Nets',
#                                                                                   'point': -11.0,
#                                                                                   'price': -108},
#                                                                               {   'name': 'Detroit '
#                                                                                           'Pistons',
#                                                                                   'point': 11.0,
#                                                                                   'price': -113}]},
#                                            'DraftKings': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                     'Nets',
#                                                                             'price': -580},
#                                                                         {   'name': 'Detroit '
#                                                                                     'Pistons',
#                                                                             'price': 440}],
#                                                              'spreads': [   {   'name': 'Brooklyn '
#                                                                                         'Nets',
#                                                                                 'point': -11.0,
#                                                                                 'price': -110},
#                                                                             {   'name': 'Detroit '
#                                                                                         'Pistons',
#                                                                                 'point': 11.0,
#                                                                                 'price': -110}]},
#                                            'FOX Bet': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                  'Nets',
#                                                                          'price': -667},
#                                                                      {   'name': 'Detroit '
#                                                                                  'Pistons',
#                                                                          'price': 375}],
#                                                           'spreads': [   {   'name': 'Brooklyn '
#                                                                                      'Nets',
#                                                                              'point': -11.0,
#                                                                              'price': -110},
#                                                                          {   'name': 'Detroit '
#                                                                                      'Pistons',
#                                                                              'point': 11.0,
#                                                                              'price': -110}]},
#                                            'FanDuel': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                  'Nets',
#                                                                          'price': -550},
#                                                                      {   'name': 'Detroit '
#                                                                                  'Pistons',
#                                                                          'price': 410}],
#                                                           'spreads': [   {   'name': 'Brooklyn '
#                                                                                      'Nets',
#                                                                              'point': -11.0,
#                                                                              'price': -110},
#                                                                          {   'name': 'Detroit '
#                                                                                      'Pistons',
#                                                                              'point': 11.0,
#                                                                              'price': -110}]},
#                                            'LowVig.ag': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                    'Nets',
#                                                                            'price': -549},
#                                                                        {   'name': 'Detroit '
#                                                                                    'Pistons',
#                                                                            'price': 430}],
#                                                             'spreads': [   {   'name': 'Brooklyn '
#                                                                                        'Nets',
#                                                                                'point': -11.0,
#                                                                                'price': -108},
#                                                                            {   'name': 'Detroit '
#                                                                                        'Pistons',
#                                                                                'point': 11.0,
#                                                                                'price': -102}]},
#                                            'MyBookie.ag': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                      'Nets',
#                                                                              'price': -580},
#                                                                          {   'name': 'Detroit '
#                                                                                      'Pistons',
#                                                                              'price': 430}],
#                                                               'spreads': [   {   'name': 'Brooklyn '
#                                                                                          'Nets',
#                                                                                  'point': -11.0,
#                                                                                  'price': -110},
#                                                                              {   'name': 'Detroit '
#                                                                                          'Pistons',
#                                                                                  'point': 11.0,
#                                                                                  'price': -110}]},
#                                            'PointsBet (US)': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                         'Nets',
#                                                                                 'price': -575},
#                                                                             {   'name': 'Detroit '
#                                                                                         'Pistons',
#                                                                                 'price': 425}],
#                                                                  'spreads': [   {   'name': 'Brooklyn '
#                                                                                             'Nets',
#                                                                                     'point': -11.0,
#                                                                                     'price': -110},
#                                                                                 {   'name': 'Detroit '
#                                                                                             'Pistons',
#                                                                                     'point': 11.0,
#                                                                                     'price': -110}]},
#                                            'SugarHouse': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                     'Nets',
#                                                                             'price': -590},
#                                                                         {   'name': 'Detroit '
#                                                                                     'Pistons',
#                                                                             'price': 430}],
#                                                              'spreads': [   {   'name': 'Brooklyn '
#                                                                                         'Nets',
#                                                                                 'point': -11.0,
#                                                                                 'price': -110},
#                                                                             {   'name': 'Detroit '
#                                                                                         'Pistons',
#                                                                                 'point': 11.0,
#                                                                                 'price': -110}]},
#                                            'SuperBook': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                    'Nets',
#                                                                            'price': -600},
#                                                                        {   'name': 'Detroit '
#                                                                                    'Pistons',
#                                                                            'price': 450}],
#                                                             'spreads': [   {   'name': 'Brooklyn '
#                                                                                        'Nets',
#                                                                                'point': -11.0,
#                                                                                'price': -110},
#                                                                            {   'name': 'Detroit '
#                                                                                        'Pistons',
#                                                                                'point': 11.0,
#                                                                                'price': -110}]},
#                                            'TwinSpires': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                     'Nets',
#                                                                             'price': -590},
#                                                                         {   'name': 'Detroit '
#                                                                                     'Pistons',
#                                                                             'price': 430}],
#                                                              'spreads': [   {   'name': 'Brooklyn '
#                                                                                         'Nets',
#                                                                                 'point': -11.0,
#                                                                                 'price': -110},
#                                                                             {   'name': 'Detroit '
#                                                                                         'Pistons',
#                                                                                 'point': 11.0,
#                                                                                 'price': -110}]},
#                                            'Unibet': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                 'Nets',
#                                                                         'price': -590},
#                                                                     {   'name': 'Detroit '
#                                                                                 'Pistons',
#                                                                         'price': 430}],
#                                                          'spreads': [   {   'name': 'Brooklyn '
#                                                                                     'Nets',
#                                                                             'point': -11.0,
#                                                                             'price': -110},
#                                                                         {   'name': 'Detroit '
#                                                                                     'Pistons',
#                                                                             'point': 11.0,
#                                                                             'price': -110}]},
#                                            'William Hill (US)': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                            'Nets',
#                                                                                    'price': -600},
#                                                                                {   'name': 'Detroit '
#                                                                                            'Pistons',
#                                                                                    'price': 430}],
#                                                                     'spreads': [   {   'name': 'Brooklyn '
#                                                                                                'Nets',
#                                                                                        'point': -11.5,
#                                                                                        'price': -110},
#                                                                                    {   'name': 'Detroit '
#                                                                                                'Pistons',
#                                                                                        'point': 11.5,
#                                                                                        'price': -110}]},
#                                            'WynnBET': {   'h2h': [   {   'name': 'Brooklyn '
#                                                                                  'Nets',
#                                                                          'price': -588},
#                                                                      {   'name': 'Detroit '
#                                                                                  'Pistons',
#                                                                          'price': 420}],
#                                                           'spreads': [   {   'name': 'Brooklyn '
#                                                                                      'Nets',
#                                                                              'point': -11.0,
#                                                                              'price': -110},
#                                                                          {   'name': 'Detroit '
#                                                                                      'Pistons',
#                                                                              'point': 11.0,
#                                                                              'price': -110}]}},
#     'Chicago Bulls @ Milwaukee Bucks': {   'Barstool Sportsbook': {   'h2h': [   {   'name': 'Chicago '
#                                                                                              'Bulls',
#                                                                                      'price': 215},
#                                                                                  {   'name': 'Milwaukee '
#                                                                                              'Bucks',
#                                                                                      'price': -265}],
#                                                                       'spreads': [   {   'name': 'Chicago '
#                                                                                                  'Bulls',
#                                                                                          'point': 7.0,
#                                                                                          'price': -114},
#                                                                                      {   'name': 'Milwaukee '
#                                                                                                  'Bucks',
#                                                                                          'point': -7.0,
#                                                                                          'price': -107}]},
#                                            'BetMGM': {   'h2h': [   {   'name': 'Chicago '
#                                                                                 'Bulls',
#                                                                         'price': 240},
#                                                                     {   'name': 'Milwaukee '
#                                                                                 'Bucks',
#                                                                         'price': -300}],
#                                                          'spreads': [   {   'name': 'Chicago '
#                                                                                     'Bulls',
#                                                                             'point': 7.5,
#                                                                             'price': -110},
#                                                                         {   'name': 'Milwaukee '
#                                                                                     'Bucks',
#                                                                             'point': -7.5,
#                                                                             'price': -110}]},
#                                            'BetOnline.ag': {   'h2h': [   {   'name': 'Chicago '
#                                                                                       'Bulls',
#                                                                               'price': 250},
#                                                                           {   'name': 'Milwaukee '
#                                                                                       'Bucks',
#                                                                               'price': -303}],
#                                                                'spreads': [   {   'name': 'Chicago '
#                                                                                           'Bulls',
#                                                                                   'point': 7.5,
#                                                                                   'price': -111},
#                                                                               {   'name': 'Milwaukee '
#                                                                                           'Bucks',
#                                                                                   'point': -7.5,
#                                                                                   'price': -111}]},
#                                            'BetRivers': {   'h2h': [   {   'name': 'Chicago '
#                                                                                    'Bulls',
#                                                                            'price': 215},
#                                                                        {   'name': 'Milwaukee '
#                                                                                    'Bucks',
#                                                                            'price': -265}],
#                                                             'spreads': [   {   'name': 'Chicago '
#                                                                                        'Bulls',
#                                                                                'point': 7.0,
#                                                                                'price': -114},
#                                                                            {   'name': 'Milwaukee '
#                                                                                        'Bucks',
#                                                                                'point': -7.0,
#                                                                                'price': -107}]},
#                                            'BetUS': {   'h2h': [   {   'name': 'Chicago '
#                                                                                'Bulls',
#                                                                        'price': 240},
#                                                                    {   'name': 'Milwaukee '
#                                                                                'Bucks',
#                                                                        'price': -290}],
#                                                         'spreads': [   {   'name': 'Chicago '
#                                                                                    'Bulls',
#                                                                            'point': 7.5,
#                                                                            'price': -110},
#                                                                        {   'name': 'Milwaukee '
#                                                                                    'Bucks',
#                                                                            'point': -7.5,
#                                                                            'price': -110}]},
#                                            'Bovada': {   'h2h': [   {   'name': 'Chicago '
#                                                                                 'Bulls',
#                                                                         'price': 230},
#                                                                     {   'name': 'Milwaukee '
#                                                                                 'Bucks',
#                                                                         'price': -280}],
#                                                          'spreads': [   {   'name': 'Chicago '
#                                                                                     'Bulls',
#                                                                             'point': 7.5,
#                                                                             'price': -110},
#                                                                         {   'name': 'Milwaukee '
#                                                                                     'Bucks',
#                                                                             'point': -7.5,
#                                                                             'price': -110}]},
#                                            'Circa Sports': {   'h2h': [   {   'name': 'Chicago '
#                                                                                       'Bulls',
#                                                                               'price': 236},
#                                                                           {   'name': 'Milwaukee '
#                                                                                       'Bucks',
#                                                                               'price': -304}],
#                                                                'spreads': [   {   'name': 'Chicago '
#                                                                                           'Bulls',
#                                                                                   'point': 7.5,
#                                                                                   'price': -110},
#                                                                               {   'name': 'Milwaukee '
#                                                                                           'Bucks',
#                                                                                   'point': -7.5,
#                                                                                   'price': -110}]},
#                                            'DraftKings': {   'h2h': [   {   'name': 'Chicago '
#                                                                                     'Bulls',
#                                                                             'price': 245},
#                                                                         {   'name': 'Milwaukee '
#                                                                                     'Bucks',
#                                                                             'price': -295}],
#                                                              'spreads': [   {   'name': 'Chicago '
#                                                                                         'Bulls',
#                                                                                 'point': 7.5,
#                                                                                 'price': -110},
#                                                                             {   'name': 'Milwaukee '
#                                                                                         'Bucks',
#                                                                                 'point': -7.5,
#                                                                                 'price': -110}]},
#                                            'FOX Bet': {   'h2h': [   {   'name': 'Chicago '
#                                                                                  'Bulls',
#                                                                          'price': 220},
#                                                                      {   'name': 'Milwaukee '
#                                                                                  'Bucks',
#                                                                          'price': -333}],
#                                                           'spreads': [   {   'name': 'Chicago '
#                                                                                      'Bulls',
#                                                                              'point': 7.0,
#                                                                              'price': -118},
#                                                                          {   'name': 'Milwaukee '
#                                                                                      'Bucks',
#                                                                              'point': -7.0,
#                                                                              'price': -105}]},
#                                            'FanDuel': {   'h2h': [   {   'name': 'Chicago '
#                                                                                  'Bulls',
#                                                                          'price': 235},
#                                                                      {   'name': 'Milwaukee '
#                                                                                  'Bucks',
#                                                                          'price': -290}],
#                                                           'spreads': [   {   'name': 'Chicago '
#                                                                                      'Bulls',
#                                                                              'point': 7.5,
#                                                                              'price': -114},
#                                                                          {   'name': 'Milwaukee '
#                                                                                      'Bucks',
#                                                                              'point': -7.5,
#                                                                              'price': -106}]},
#                                            'LowVig.ag': {   'h2h': [   {   'name': 'Chicago '
#                                                                                    'Bulls',
#                                                                            'price': 250},
#                                                                        {   'name': 'Milwaukee '
#                                                                                    'Bucks',
#                                                                            'price': -300}],
#                                                             'spreads': [   {   'name': 'Chicago '
#                                                                                        'Bulls',
#                                                                                'point': 7.5,
#                                                                                'price': -105},
#                                                                            {   'name': 'Milwaukee '
#                                                                                        'Bucks',
#                                                                                'point': -7.5,
#                                                                                'price': -105}]},
#                                            'MyBookie.ag': {   'h2h': [   {   'name': 'Chicago '
#                                                                                      'Bulls',
#                                                                              'price': 220},
#                                                                          {   'name': 'Milwaukee '
#                                                                                      'Bucks',
#                                                                              'price': -270}],
#                                                               'spreads': [   {   'name': 'Chicago '
#                                                                                          'Bulls',
#                                                                                  'point': 7.5,
#                                                                                  'price': -110},
#                                                                              {   'name': 'Milwaukee '
#                                                                                          'Bucks',
#                                                                                  'point': -7.5,
#                                                                                  'price': -110}]},
#                                            'PointsBet (US)': {   'h2h': [   {   'name': 'Chicago '
#                                                                                         'Bulls',
#                                                                                 'price': 240},
#                                                                             {   'name': 'Milwaukee '
#                                                                                         'Bucks',
#                                                                                 'price': -300}],
#                                                                  'spreads': [   {   'name': 'Chicago '
#                                                                                             'Bulls',
#                                                                                     'point': 7.5,
#                                                                                     'price': -110},
#                                                                                 {   'name': 'Milwaukee '
#                                                                                             'Bucks',
#                                                                                     'point': -7.5,
#                                                                                     'price': -110}]},
#                                            'SugarHouse': {   'h2h': [   {   'name': 'Chicago '
#                                                                                     'Bulls',
#                                                                             'price': 215},
#                                                                         {   'name': 'Milwaukee '
#                                                                                     'Bucks',
#                                                                             'price': -265}],
#                                                              'spreads': [   {   'name': 'Chicago '
#                                                                                         'Bulls',
#                                                                                 'point': 7.0,
#                                                                                 'price': -114},
#                                                                             {   'name': 'Milwaukee '
#                                                                                         'Bucks',
#                                                                                 'point': -7.0,
#                                                                                 'price': -107}]},
#                                            'SuperBook': {   'h2h': [   {   'name': 'Chicago '
#                                                                                    'Bulls',
#                                                                            'price': 245},
#                                                                        {   'name': 'Milwaukee '
#                                                                                    'Bucks',
#                                                                            'price': -290}],
#                                                             'spreads': [   {   'name': 'Chicago '
#                                                                                        'Bulls',
#                                                                                'point': 7.5,
#                                                                                'price': -110},
#                                                                            {   'name': 'Milwaukee '
#                                                                                        'Bucks',
#                                                                                'point': -7.5,
#                                                                                'price': -110}]},
#                                            'TwinSpires': {   'h2h': [   {   'name': 'Chicago '
#                                                                                     'Bulls',
#                                                                             'price': 215},
#                                                                         {   'name': 'Milwaukee '
#                                                                                     'Bucks',
#                                                                             'price': -265}],
#                                                              'spreads': [   {   'name': 'Chicago '
#                                                                                         'Bulls',
#                                                                                 'point': 7.0,
#                                                                                 'price': -114},
#                                                                             {   'name': 'Milwaukee '
#                                                                                         'Bucks',
#                                                                                 'point': -7.0,
#                                                                                 'price': -107}]},
#                                            'Unibet': {   'h2h': [   {   'name': 'Chicago '
#                                                                                 'Bulls',
#                                                                         'price': 215},
#                                                                     {   'name': 'Milwaukee '
#                                                                                 'Bucks',
#                                                                         'price': -265}],
#                                                          'spreads': [   {   'name': 'Chicago '
#                                                                                     'Bulls',
#                                                                             'point': 7.0,
#                                                                             'price': -114},
#                                                                         {   'name': 'Milwaukee '
#                                                                                     'Bucks',
#                                                                             'point': -7.0,
# ...
#                                                                                            'Hawks',
#                                                                                    'point': -11.5,
#                                                                                    'price': -115},
#                                                                                {   'name': 'Washington '
#                                                                                            'Wizards',
#                                                                                    'point': 11.5,
#                                                                                    'price': -105}]},
#                                               'FOX Bet': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                     'Hawks',
#                                                                             'price': -667},
#                                                                         {   'name': 'Washington '
#                                                                                     'Wizards',
#                                                                             'price': 375}],
#                                                              'spreads': [   {   'name': 'Atlanta '
#                                                                                         'Hawks',
#                                                                                 'point': -11.5,
#                                                                                 'price': -110},
#                                                                             {   'name': 'Washington '
#                                                                                         'Wizards',
#                                                                                 'point': 11.5,
#                                                                                 'price': -110}]},
#                                               'FanDuel': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                     'Hawks',
#                                                                             'price': -600},
#                                                                         {   'name': 'Washington '
#                                                                                     'Wizards',
#                                                                             'price': 450}],
#                                                              'spreads': [   {   'name': 'Atlanta '
#                                                                                         'Hawks',
#                                                                                 'point': -11.5,
#                                                                                 'price': -110},
#                                                                             {   'name': 'Washington '
#                                                                                         'Wizards',
#                                                                                 'point': 11.5,
#                                                                                 'price': -110}]},
#                                               'LowVig.ag': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                       'Hawks',
#                                                                               'price': -625},
#                                                                           {   'name': 'Washington '
#                                                                                       'Wizards',
#                                                                               'price': 485}],
#                                                                'spreads': [   {   'name': 'Atlanta '
#                                                                                           'Hawks',
#                                                                                   'point': -11.5,
#                                                                                   'price': -108},
#                                                                               {   'name': 'Washington '
#                                                                                           'Wizards',
#                                                                                   'point': 11.5,
#                                                                                   'price': -102}]},
#                                               'MyBookie.ag': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                         'Hawks',
#                                                                                 'price': -590},
#                                                                             {   'name': 'Washington '
#                                                                                         'Wizards',
#                                                                                 'price': 440}],
#                                                                  'spreads': [   {   'name': 'Atlanta '
#                                                                                             'Hawks',
#                                                                                     'point': -11.5,
#                                                                                     'price': -110},
#                                                                                 {   'name': 'Washington '
#                                                                                             'Wizards',
#                                                                                     'point': 11.5,
#                                                                                     'price': -110}]},
#                                               'PointsBet (US)': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                            'Hawks',
#                                                                                    'price': -700},
#                                                                                {   'name': 'Washington '
#                                                                                            'Wizards',
#                                                                                    'price': 475}],
#                                                                     'spreads': [   {   'name': 'Atlanta '
#                                                                                                'Hawks',
#                                                                                        'point': -11.5,
#                                                                                        'price': -110},
#                                                                                    {   'name': 'Washington '
#                                                                                                'Wizards',
#                                                                                        'point': 11.5,
#                                                                                        'price': -110}]},
#                                               'SugarHouse': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                        'Hawks',
#                                                                                'price': -625},
#                                                                            {   'name': 'Washington '
#                                                                                        'Wizards',
#                                                                                'price': 460}],
#                                                                 'spreads': [   {   'name': 'Atlanta '
#                                                                                            'Hawks',
#                                                                                    'point': -12.0,
#                                                                                    'price': -110},
#                                                                                {   'name': 'Washington '
#                                                                                            'Wizards',
#                                                                                    'point': 12.0,
#                                                                                    'price': -110}]},
#                                               'SuperBook': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                       'Hawks',
#                                                                               'price': -650},
#                                                                           {   'name': 'Washington '
#                                                                                       'Wizards',
#                                                                               'price': 475}],
#                                                                'spreads': [   {   'name': 'Atlanta '
#                                                                                           'Hawks',
#                                                                                   'point': -11.5,
#                                                                                   'price': -110},
#                                                                               {   'name': 'Washington '
#                                                                                           'Wizards',
#                                                                                   'point': 11.5,
#                                                                                   'price': -110}]},
#                                               'TwinSpires': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                        'Hawks',
#                                                                                'price': -625},
#                                                                            {   'name': 'Washington '
#                                                                                        'Wizards',
#                                                                                'price': 460}],
#                                                                 'spreads': [   {   'name': 'Atlanta '
#                                                                                            'Hawks',
#                                                                                    'point': -12.0,
#                                                                                    'price': -110},
#                                                                                {   'name': 'Washington '
#                                                                                            'Wizards',
#                                                                                    'point': 12.0,
#                                                                                    'price': -110}]},
#                                               'Unibet': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                    'Hawks',
#                                                                            'price': -625},
#                                                                        {   'name': 'Washington '
#                                                                                    'Wizards',
#                                                                            'price': 460}],
#                                                             'spreads': [   {   'name': 'Atlanta '
#                                                                                        'Hawks',
#                                                                                'point': -12.0,
#                                                                                'price': -110},
#                                                                            {   'name': 'Washington '
#                                                                                        'Wizards',
#                                                                                'point': 12.0,
#                                                                                'price': -110}]},
#                                               'William Hill (US)': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                               'Hawks',
#                                                                                       'price': -650},
#                                                                                   {   'name': 'Washington '
#                                                                                               'Wizards',
#                                                                                       'price': 460}],
#                                                                        'spreads': [   {   'name': 'Atlanta '
#                                                                                                   'Hawks',
#                                                                                           'point': -11.5,
#                                                                                           'price': -110},
#                                                                                       {   'name': 'Washington '
#                                                                                                   'Wizards',
#                                                                                           'point': 11.5,
#                                                                                           'price': -110}]},
#                                               'WynnBET': {   'h2h': [   {   'name': 'Atlanta '
#                                                                                     'Hawks',
#                                                                             'price': -667},
#                                                                         {   'name': 'Washington '
#                                                                                     'Wizards',
#                                                                             'price': 465}],
#                                                              'spreads': [   {   'name': 'Atlanta '
#                                                                                         'Hawks',
#                                                                                 'point': -11.5,
#                                                                                 'price': -110},
#                                                                             {   'name': 'Washington '
#                                                                                         'Wizards',
#                                                                                 'point': 11.5,
#                                                                                 'price': -110}]}}}

# %% [markdown]
# ## Build Data DataFrame and Visualizations

# %%
# init dataframe
df_bets = pd.DataFrame()

for game in betting_data:
    # Get the home team and away team by game and format it for easier viewing
    
    team_home = game['home_team']
    team_away = game['away_team']
    Game_ID = game['id']
    
    bookmakers = game['bookmakers']
    
    for site in bookmakers:
        site_title = site['title']
        #data_by_game[matchup][site_title] = dict()
        markets = site['markets']
        
             
        for market in markets:
            bet_format = market['key']
            bet = market['outcomes']
            
            
            # create a dictionary and add all of the required items to it 
            bet_dict = {}
            bet_dict['Game_ID'] = Game_ID
            bet_dict['bet_format'] = market['key']
            
            if bet_format == 'spreads':
                bet_dict['point_spread_away'] = bet[0]['point']
                bet_dict['point_spread_home'] = bet[1]['point']
            else:
                bet_dict['point_spread_away'] = 0
                bet_dict['point_spread_home'] = 0
            
            bet_dict['site_title'] = site_title
            bet_dict['home_team'] = team_home
            bet_dict['away_team'] = team_away
            
            bet_dict['price_away'] = bet[0]['price']
            bet_dict['price_home'] = bet[1]['price']
            
            df_bets = df_bets.append(bet_dict, ignore_index = True)

# %%
df_bets_grouped = df_bets.groupby('Game_ID')

# %%
# bool index to head to head bets 
h2h = df_bets['bet_format'] == 'h2h'
df_bets_h2h = df_bets.loc[h2h, :]


#Now for set game ID as inidexing to try and simply the viz 
df_bets_h2h = df_bets_h2h.set_index('Game_ID')

# lets look at the first game 
game_1 = df_bets_h2h.loc[df_bets_h2h.index[0]]


#Import some additional packages
import matplotlib.pyplot as plt
import seaborn as sns


# Building a vizualisaiton best for the 10 options from our dataset to show that there is a significant difference
sns.set()
chart = sns.barplot(x="site_title",y = "price_away",data= game_1.iloc[:10])
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_xlabel("Bookie", fontsize = 20)
chart.set_ylabel("Price for Home Team bet ", fontsize = 20)

home_team_Str = game_1['home_team'][0]
away_team_Str = game_1['away_team'][0]

chart.set_title(f'{home_team_Str} @ {away_team_Str} ', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Detroit Pistons @ Brooklyn Nets ')

# %%
## Very similar to the one abovea

game_2 = df_bets_h2h.loc[df_bets_h2h.index[44]]

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
chart = sns.barplot(x="site_title",y = "price_away",data= game_2.iloc[:10])
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_xlabel("Bookie", fontsize = 20)
chart.set_ylabel("Price for Home Team bet ", fontsize = 20)

home_team_Str = game_2['home_team'][0]
away_team_Str = game_2['away_team'][0]

chart.set_title(f'{away_team_Str} @ {home_team_Str}', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Washington Wizards @ Atlanta Hawks')

# %%
df_bets
# Out:
#                               Game_ID               away_team bet_format  \
# 0    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets        h2h
# 1    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets    spreads
# 2    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets        h2h
# 3    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets    spreads
# 4    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets        h2h
# ..                                ...                     ...        ...
# 313  2334038527da069380744c90394fd32b  Portland Trail Blazers    spreads
# 314  9be202f0128b562bd90ffa71a8b39ae8   Oklahoma City Thunder        h2h
# 315  9be202f0128b562bd90ffa71a8b39ae8   Oklahoma City Thunder    spreads
# 316  9968b769c7b7f93ac70841e64d6ffeea          Denver Nuggets        h2h
# 317  9968b769c7b7f93ac70841e64d6ffeea          Denver Nuggets    spreads
#
#              home_team  point_spread_away  point_spread_home  price_away  \
# 0      Detroit Pistons                0.0                0.0      -580.0
# 1      Detroit Pistons              -11.0               11.0      -110.0
# 2      Detroit Pistons                0.0                0.0      -580.0
# 3      Detroit Pistons              -11.0               11.0      -110.0
# 4      Detroit Pistons                0.0                0.0      -556.0
# ..                 ...                ...                ...         ...
# 313  San Antonio Spurs                2.5               -2.5      -110.0
# 314          Utah Jazz                0.0                0.0      -200.0
# 315          Utah Jazz               -5.0                5.0      -110.0
# 316       Phoenix Suns                0.0                0.0       160.0
# 317       Phoenix Suns                4.5               -4.5      -110.0
#
#      price_home    site_title
# 0         440.0    DraftKings
# 1        -110.0    DraftKings
# 2         430.0   MyBookie.ag
# 3        -110.0   MyBookie.ag
# 4         430.0  BetOnline.ag
# ..          ...           ...
# 313      -110.0    DraftKings
# 314       170.0    DraftKings
# 315      -110.0    DraftKings
# 316      -190.0    DraftKings
# 317      -110.0    DraftKings
#
# [318 rows x 9 columns]

# %%
df_bets_ = df_bets.set_index('Game_ID','site_title')

# Get just the h2h odds
h2h = df_bets_['bet_format'] == 'h2h'
df_bets_h2h = df_bets_.loc[h2h, :]

# Select what columns we want to keep to make the dataframe easier to work with
df_bets_h2h = df_bets_h2h[['bet_format', 'away_team', 'home_team', 'price_home', 'site_title']]
min_home_odds = df_bets_h2h.groupby('home_team')['price_home'].min()

min_odds_dict = min_home_odds.to_dict()

# %%
min_site_counts = list()


for key, value in min_odds_dict.items():
    row = df_bets_h2h.loc[(df_bets_h2h['home_team'] == key) & (df_bets_h2h['price_home'] == value)]
    site = row['site_title']
    min_site_counts += list(site.values)

min_site_counts
# Out:
# ['FOX Bet',
#  'FOX Bet',
#  'Circa Sports',
#  'FOX Bet',
#  'PointsBet (US)',
#  'FOX Bet',
#  'FOX Bet',
#  'Circa Sports',
#  'FOX Bet',
#  'FOX Bet',
#  'DraftKings',
#  'DraftKings',
#  'DraftKings',
#  'DraftKings',
#  'DraftKings']

# %%
from collections import Counter

site_counts = dict(Counter(min_site_counts))

# Initialize lists for pie chart
labels = list()
sizes = list()

# Split up dictionary into separate lists
for site, count in site_counts.items():
    labels.append(site)
    sizes.append(count)
    
plt.pie(sizes, labels = labels, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Percentage of Best Odds by Site')
plt.show()

# %%
home_team = []
dist_from_avg = []

# find average of each bet across all sportsbooks, then subtract that average from the spread and store the result in a list
for i in df_bets.index:
    home_team.append(df_bets['home_team'].iloc[i])
    avg = df_bets.loc[df_bets['home_team'] == home_team[i], 'point_spread_home'].mean()
    dist_from_avg.append(df_bets['point_spread_home'].iloc[i] - avg)
    
print(len(home_team))
print(len(dist_from_avg))
# Out:
# 318
# 318

# %%
# add distance from average column
df_bets["dist_from_mean"] = dist_from_avg

# set all rows with no point spread info to 0
df_bets.loc[df_bets['point_spread_home'] == 0, 'dist_from_mean'] = 0
df_bets = df_bets.round(1)

df_bets
# Out:
#                               Game_ID               away_team bet_format  \
# 0    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets        h2h
# 1    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets    spreads
# 2    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets        h2h
# 3    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets    spreads
# 4    8aa4612b180d52ecb170150491f9a34d           Brooklyn Nets        h2h
# ..                                ...                     ...        ...
# 313  2334038527da069380744c90394fd32b  Portland Trail Blazers    spreads
# 314  9be202f0128b562bd90ffa71a8b39ae8   Oklahoma City Thunder        h2h
# 315  9be202f0128b562bd90ffa71a8b39ae8   Oklahoma City Thunder    spreads
# 316  9968b769c7b7f93ac70841e64d6ffeea          Denver Nuggets        h2h
# 317  9968b769c7b7f93ac70841e64d6ffeea          Denver Nuggets    spreads
#
#              home_team  point_spread_away  point_spread_home  price_away  \
# 0      Detroit Pistons                0.0                0.0      -580.0
# 1      Detroit Pistons              -11.0               11.0      -110.0
# 2      Detroit Pistons                0.0                0.0      -580.0
# 3      Detroit Pistons              -11.0               11.0      -110.0
# 4      Detroit Pistons                0.0                0.0      -556.0
# ..                 ...                ...                ...         ...
# 313  San Antonio Spurs                2.5               -2.5      -110.0
# 314          Utah Jazz                0.0                0.0      -200.0
# 315          Utah Jazz               -5.0                5.0      -110.0
# 316       Phoenix Suns                0.0                0.0       160.0
# 317       Phoenix Suns                4.5               -4.5      -110.0
#
#      price_home    site_title  dist_from_mean
# 0         440.0    DraftKings             0.0
# 1        -110.0    DraftKings             5.5
# 2         430.0   MyBookie.ag             0.0
# 3        -110.0   MyBookie.ag             5.5
# 4         430.0  BetOnline.ag             0.0
# ..          ...           ...             ...
# 313      -110.0    DraftKings            -1.2
# 314       170.0    DraftKings             0.0
# 315      -110.0    DraftKings             2.5
# 316      -190.0    DraftKings             0.0
# 317      -110.0    DraftKings            -2.2
#
# [318 rows x 10 columns]

# %%
df_bets.to_csv("NBA_Bets.csv", encoding='utf-8', index=False)
